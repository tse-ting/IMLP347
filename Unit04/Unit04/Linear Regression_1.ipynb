# %% [markdown]
# # Linear Regression

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## 1. 線性迴歸基本概念

# %% [markdown]
# #### 直線
#
# $$f(x) = 1.2x + 0.8$$

# %%
#準備 50 個點
#5-0/50 = 0.1 +....
# 0~5線性切割
x = np.linspace(0, 5, 50)
print(x)
# Out:
# [0.         0.10204082 0.20408163 0.30612245 0.40816327 0.51020408
#  0.6122449  0.71428571 0.81632653 0.91836735 1.02040816 1.12244898
#  1.2244898  1.32653061 1.42857143 1.53061224 1.63265306 1.73469388
#  1.83673469 1.93877551 2.04081633 2.14285714 2.24489796 2.34693878
#  2.44897959 2.55102041 2.65306122 2.75510204 2.85714286 2.95918367
#  3.06122449 3.16326531 3.26530612 3.36734694 3.46938776 3.57142857
#  3.67346939 3.7755102  3.87755102 3.97959184 4.08163265 4.18367347
#  4.28571429 4.3877551  4.48979592 4.59183673 4.69387755 4.79591837
#  4.89795918 5.        ]

# %%
y = 1.2*x + 0.8
y
# Out:
# array([0.8       , 0.92244898, 1.04489796, 1.16734694, 1.28979592,
#        1.4122449 , 1.53469388, 1.65714286, 1.77959184, 1.90204082,
#        2.0244898 , 2.14693878, 2.26938776, 2.39183673, 2.51428571,
#        2.63673469, 2.75918367, 2.88163265, 3.00408163, 3.12653061,
#        3.24897959, 3.37142857, 3.49387755, 3.61632653, 3.73877551,
#        3.86122449, 3.98367347, 4.10612245, 4.22857143, 4.35102041,
#        4.47346939, 4.59591837, 4.71836735, 4.84081633, 4.96326531,
#        5.08571429, 5.20816327, 5.33061224, 5.45306122, 5.5755102 ,
#        5.69795918, 5.82040816, 5.94285714, 6.06530612, 6.1877551 ,
#        6.31020408, 6.43265306, 6.55510204, 6.67755102, 6.8       ])

# %%
#畫圖
plt.scatter(x,y)
plt.plot(x, 1.2*x+0.8, 'r')

# %% [markdown]
# #### add noise
#
# $$f(x) + \varepsilon(x)$$

# %%
y = 1.2*x + 0.8 + 0.6*np.random.randn(50)
print(y)
# Out:
# [0.92473543 1.94599558 0.74300064 1.75216696 1.05834155 0.97318372
#  1.39186059 1.21779149 2.10214014 2.66988376 2.90570631 2.46025314
#  3.16145127 2.09418198 2.8081132  2.40304009 3.00606604 2.23683606
#  2.50733863 2.61115195 3.85284845 3.05861649 3.63333413 4.35673391
#  4.1972573  3.30243281 4.66979967 4.79166168 4.63091084 5.27761651
#  5.38337559 4.93897779 4.62929892 4.9547088  5.12788218 4.71481306
#  6.70017701 4.2791438  5.05221343 5.9303056  6.43571897 7.45752331
#  5.41939539 6.93835063 6.93352079 6.6257982  7.07317705 7.08209531
#  6.57234431 6.51861392]

# %%
plt.scatter(x,y)
plt.plot(x, 1.2*x + 0.8, 'r')

# %%
from sklearn.linear_model import LinearRegression
regr = LinearRegression()

# %%
regr
# Out:
# LinearRegression()

# %% [markdown]
# 要求資料轉換<br>
#
# $$[x_1, x_2, \ldots, x_{50}]$$
#
# ==>
#
# $$[[x_1], [x_2], \ldots, [x_{50}]]$$
#
#
# 矩陣的概念

# %%
print(x.shape)
X = x.reshape(-1,1)
X.shape
# Out:
# (50,)
# (50, 1)

# %%
regr.fit(X,y)
# Out:
# LinearRegression()

# %%
Y = regr.predict(X)
print(Y)
# Out:
# [0.90525107 1.03280154 1.16035202 1.28790249 1.41545296 1.54300344
#  1.67055391 1.79810439 1.92565486 2.05320534 2.18075581 2.30830628
#  2.43585676 2.56340723 2.69095771 2.81850818 2.94605866 3.07360913
#  3.2011596  3.32871008 3.45626055 3.58381103 3.7113615  3.83891198
#  3.96646245 4.09401293 4.2215634  4.34911387 4.47666435 4.60421482
#  4.7317653  4.85931577 4.98686625 5.11441672 5.24196719 5.36951767
#  5.49706814 5.62461862 5.75216909 5.87971957 6.00727004 6.13482051
#  6.26237099 6.38992146 6.51747194 6.64502241 6.77257289 6.90012336
#  7.02767384 7.15522431]

# %%
#了解你的訓練參數
regr.get_params()
# Out:
# {'copy_X': True, 'fit_intercept': True, 'n_jobs': None, 'positive': False}

# %%
plt.scatter(x, y) #原本 
plt.plot(x, Y, 'ro') #預測
#calculate mse
mse = np.sum((Y-y)**2) / len(y)
print(mse)
# Out:
# 0.3315064186570755

# %%
#Y=WX+b
W=regr.coef_#斜率
W
# Out:
# array([1.24999465])

# %%
b=regr.intercept_ #截距
b
# Out:
# 0.9052510667923843

# %%
Y
# Out:
# array([0.90525107, 1.03280154, 1.16035202, 1.28790249, 1.41545296,
#        1.54300344, 1.67055391, 1.79810439, 1.92565486, 2.05320534,
#        2.18075581, 2.30830628, 2.43585676, 2.56340723, 2.69095771,
#        2.81850818, 2.94605866, 3.07360913, 3.2011596 , 3.32871008,
#        3.45626055, 3.58381103, 3.7113615 , 3.83891198, 3.96646245,
#        4.09401293, 4.2215634 , 4.34911387, 4.47666435, 4.60421482,
#        4.7317653 , 4.85931577, 4.98686625, 5.11441672, 5.24196719,
#        5.36951767, 5.49706814, 5.62461862, 5.75216909, 5.87971957,
#        6.00727004, 6.13482051, 6.26237099, 6.38992146, 6.51747194,
#        6.64502241, 6.77257289, 6.90012336, 7.02767384, 7.15522431])

# %%
#可以將新的x資料帶入算出結果
W*3+b
# Out:
# array([4.65523501])

# %%
y
# Out:
# array([0.92473543, 1.94599558, 0.74300064, 1.75216696, 1.05834155,
#        0.97318372, 1.39186059, 1.21779149, 2.10214014, 2.66988376,
#        2.90570631, 2.46025314, 3.16145127, 2.09418198, 2.8081132 ,
#        2.40304009, 3.00606604, 2.23683606, 2.50733863, 2.61115195,
#        3.85284845, 3.05861649, 3.63333413, 4.35673391, 4.1972573 ,
#        3.30243281, 4.66979967, 4.79166168, 4.63091084, 5.27761651,
#        5.38337559, 4.93897779, 4.62929892, 4.9547088 , 5.12788218,
#        4.71481306, 6.70017701, 4.2791438 , 5.05221343, 5.9303056 ,
#        6.43571897, 7.45752331, 5.41939539, 6.93835063, 6.93352079,
#        6.6257982 , 7.07317705, 7.08209531, 6.57234431, 6.51861392])
